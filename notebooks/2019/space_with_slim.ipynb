# %%
import os
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
# setup: has to be in a separate cell for some reason
plt.rcParams['figure.figsize'] = [8, 8]

# %%
# from last time
def slim_script(script, name, quiet=False):
    logfile = name + ".log"
    out = os.system("echo '" + script + "' | slim > " + logfile + " 2>&1")
    if not quiet:
        with open(logfile, "r") as log:
            print(log.read())
    if out != 0:
        print("An error occurred.")
    return out, logfile

# %% [markdown]
# # Adding geography
#
# In reality, all individual interactions are *local*, to some degree.
# This can have important effects on the population dynamics in a lot of ways
# (sometimes hard to predict), for instance:
#
# - *sources and sinks*: some places are better than others
# - *local inbreeding*: spatial mate choice can reduce diversity
# - *buffering*: local bad years ameliorated by immigration from elsewhere
#
# We'll start on this by implementing a spatial logistic population model.

# %% [markdown]
# # Spatial logistic model
#
# We'll start with a model on a single type/species,
# in which the population doesn't blow up because the fecundity goes down with population size:
#
# 1. Everyone has a Poisson($\lambda / (1 + N/K)$) number of babies<br>
#     a. with a randomly chosen mate.
# 2. Everyone dies with probability $\mu$.
#
# This should equilibrate around where the birth and death rates are equal
# (actually, where birth-plus-surviving-to-adulthood and adult-death rates are equal),
# at $N_* = K(\lambda(1-\mu)/\mu - 1)$.

# %%
logistic_fecundity_recipe = """
initialize() {
    initializeSLiMModelType("nonWF");
    initializeMutationRate(1e-7);
    initializeMutationType("m1", 0.5, "f", 0.0);
    initializeGenomicElementType("g1", m1, 1.0);
    initializeGenomicElement(g1, 0, 99999);
    initializeRecombinationRate(1e-8);    

    defineConstant("LAMBDA", 2.0); // birth rate
    defineConstant("K", 100);      // carrying capacity
    defineConstant("MU", 0.5);      // death rate
}

// the reproduction callback only applies to p2 (adults)
reproduction() {
    num_offspring = rpois(1, LAMBDA / (1 + p1.individualCount / K));
    for (k in seqLen(num_offspring)) {
        p1.addCrossed(individual, subpop.sampleIndividuals(1));
    }
}

1 early() {
    // initial population
    sim.addSubpop("p1", K);
}


early() {
    // survival probabilities
    p1.fitnessScaling = 1 - MU;
}

1: early() {
    cat(sim.generation + " : population size, early :" + p1.individualCount);
}

1: late() {
    catn( " : late :" + p1.individualCount);
}

100 {
    sim.simulationFinished();
}
"""
out, logfile = slim_script(logistic_fecundity_recipe, "logistic_fecundity_recipe")
# Out:
# // Initial random seed:
# 1860026357959
#
# // RunInitializeCallbacks():
# initializeSLiMModelType(modelType = 'nonWF');
# initializeMutationRate(1e-07);
# initializeMutationType(1, 0.5, "f", 0);
# initializeGenomicElementType(1, m1, 1);
# initializeGenomicElement(g1, 0, 99999);
# initializeRecombinationRate(1e-08);
#
# // Starting run at generation <start>:
# 1
#
# 1 : population size, early :100 : late :50
# 2 : population size, early :102 : late :59
# 3 : population size, early :126 : late :67
# 4 : population size, early :143 : late :75
# 5 : population size, early :132 : late :63
# 6 : population size, early :149 : late :69
# 7 : population size, early :145 : late :69
# 8 : population size, early :150 : late :80
# 9 : population size, early :188 : late :78
# 10 : population size, early :163 : late :79
# 11 : population size, early :178 : late :89
# 12 : population size, early :194 : late :88
# 13 : population size, early :194 : late :99
# 14 : population size, early :200 : late :96
# 15 : population size, early :218 : late :127
# 16 : population size, early :241 : late :109
# 17 : population size, early :209 : late :101
# 18 : population size, early :218 : late :114
# 19 : population size, early :221 : late :108
# 20 : population size, early :220 : late :115
# 21 : population size, early :215 : late :115
# 22 : population size, early :213 : late :105
# 23 : population size, early :206 : late :106
# 24 : population size, early :199 : late :106
# 25 : population size, early :204 : late :110
# 26 : population size, early :215 : late :100
# 27 : population size, early :197 : late :97
# 28 : population size, early :195 : late :97
# 29 : population size, early :183 : late :89
# 30 : population size, early :196 : late :97
# 31 : population size, early :213 : late :109
# 32 : population size, early :210 : late :108
# 33 : population size, early :191 : late :94
# 34 : population size, early :191 : late :96
# 35 : population size, early :184 : late :93
# 36 : population size, early :189 : late :99
# 37 : population size, early :207 : late :101
# 38 : population size, early :188 : late :97
# 39 : population size, early :188 : late :106
# 40 : population size, early :223 : late :113
# 41 : population size, early :211 : late :110
# 42 : population size, early :216 : late :112
# 43 : population size, early :218 : late :110
# 44 : population size, early :221 : late :111
# 45 : population size, early :237 : late :117
# 46 : population size, early :224 : late :113
# 47 : population size, early :229 : late :113
# 48 : population size, early :235 : late :124
# 49 : population size, early :226 : late :116
# 50 : population size, early :233 : late :106
# 51 : population size, early :212 : late :103
# 52 : population size, early :204 : late :106
# 53 : population size, early :195 : late :114
# 54 : population size, early :215 : late :101
# 55 : population size, early :210 : late :105
# 56 : population size, early :210 : late :108
# 57 : population size, early :227 : late :128
# 58 : population size, early :235 : late :126
# 59 : population size, early :242 : late :124
# 60 : population size, early :218 : late :119
# 61 : population size, early :230 : late :114
# 62 : population size, early :220 : late :96
# 63 : population size, early :188 : late :82
# 64 : population size, early :167 : late :82
# 65 : population size, early :179 : late :90
# 66 : population size, early :186 : late :92
# 67 : population size, early :180 : late :80
# 68 : population size, early :165 : late :86
# 69 : population size, early :188 : late :95
# 70 : population size, early :188 : late :99
# 71 : population size, early :210 : late :98
# 72 : population size, early :189 : late :85
# 73 : population size, early :199 : late :92
# 74 : population size, early :195 : late :92
# 75 : population size, early :189 : late :97
# 76 : population size, early :193 : late :91
# 77 : population size, early :177 : late :95
# 78 : population size, early :200 : late :97
# 79 : population size, early :208 : late :111
# 80 : population size, early :217 : late :112
# 81 : population size, early :214 : late :107
# 82 : population size, early :229 : late :125
# 83 : population size, early :208 : late :105
# 84 : population size, early :209 : late :111
# 85 : population size, early :223 : late :117
# 86 : population size, early :231 : late :109
# 87 : population size, early :234 : late :114
# 88 : population size, early :209 : late :113
# 89 : population size, early :213 : late :110
# 90 : population size, early :199 : late :93
# 91 : population size, early :184 : late :89
# 92 : population size, early :204 : late :111
# 93 : population size, early :223 : late :110
# 94 : population size, early :213 : late :103
# 95 : population size, early :199 : late :91
# 96 : population size, early :174 : late :77
# 97 : population size, early :158 : late :72
# 98 : population size, early :157 : late :89
# 99 : population size, early :187 : late :101
# 100 : population size, early :189 : late :98

# %% [markdown]
# ## Interactions
#
# Making a SLiM simulation "spatial" involves two steps:
# 1. Setting the *dimensionality* of space (either 'x', 'xy', or 'xyz'),
#     with e.g., `initializeSLiMOptions(dimensionality='xy')`,
#     giving individuals (and their offspring) spatial locations, and
# 2. Setting up *interactions* to mediate everything you want to be spatial.

# %% [markdown]
# ### Spatial position
#
# Telling SLiM it will be a spatial simulation with `dimensionality='xy'`
# option makes it so that all invdividuals have new attributes, `.x` and `.y`, and also `spatialPosition` (which is `(x,y)`).
# The first things to do are to (1) initialize spatial positions:
# ```
# 1 early() {
#     sim.addSubpop("p1", K);
#     sim.setSpatialBounds(c(0, 0, 100, 100));
#     for (ind in p1.individuals) {
#         ind.spatialPosition = p1.pointUniform();
#     }
# }
# ```
# and (2) make them heritable:
# ```
# reproduction() {
#     num_offspring = rpois(1, LAMBDA / (1 + p1.individualCount / K));
#     for (k in seqLen(num_offspring)) {
#         offspring = p1.addCrossed(individual, subpop.sampleIndividuals(1));
#         pos = individual.spatialPosition + rnorm(2, 0, SIGMA);
#         offspring.setSpatialPosition(p1.pointReflected(pos));
#     }
# }
# ```

# %% [markdown]
# ### Spatial interactions
#
# *Interactions* are how SLiM handles all the overhead of looking up
# "who is close to who", more or less.
# More concretely, an *interaction* lets you find out,
# for each individual, the *distance* and *interaction strength*
# to every other individual within some *maximum interaction distance*.
# "Interaction strength" is just putting the distance through a function
# (that gets smaller with bigger distances);
# a usual choice is the Normal density ("n").
# We will use one to make the number of nearby individuals
# decrease fecundity.
#
# First, we have to initialize it:
# ```
#     // spatial interaction for local competition
#     initializeInteractionType("i1", "xy", reciprocal=T,
#                 maxDistance=3 * SIGMA);
#     i1.setInteractionFunction("n", 1.0/(2*PI*SIGMA^2), SIGMA);
# ```
# (The choice of $1/(2 \pi \sigma^2)$ for the max strength
# makes the sum of all interactions have units of
# individuals per unit area.)
#
# Then, in `reproduction()`, we use it:
# ```
# reproduction() {
#     num_neighbors = i1.totalOfNeighborStrengths(individual);
#     num_offspring = rpois(1, LAMBDA / (1 + num_neighbors / K));
# ```

# %%
spatial_logistic_fecundity_recipe = """
initialize() {
    initializeSLiMModelType("nonWF");
    initializeSLiMOptions(dimensionality="xy");
    initializeMutationRate(1e-7);
    initializeMutationType("m1", 0.5, "f", 0.0);
    initializeGenomicElementType("g1", m1, 1.0);
    initializeGenomicElement(g1, 0, 99999);
    initializeRecombinationRate(1e-8);    

    defineConstant("LAMBDA", 2.0); // birth rate
    defineConstant("K", 1);      // carrying capacity per unit area
    defineConstant("MU", 0.5);     // death rate
    defineConstant("SIGMA", 0.5);  // interaction distance

    // output locations to here
    defineConstant("OUTFILE", "logistic_locs.txt");
    writeFile(OUTFILE, "time x y");
    
    // spatial interaction for local competition
    initializeInteractionType("i1", "xy", reciprocal=T,
                maxDistance = 3 * SIGMA);
    i1.setInteractionFunction("n", 1.0/(2*PI*SIGMA^2), SIGMA);
}

reproduction() {
    neighbor_density = i1.totalOfNeighborStrengths(individual);
    num_offspring = rpois(1, LAMBDA / (1 + neighbor_density / K));
    mate = i1.drawByStrength(individual, 1);  // single mating
    if (size(mate) > 0) {
        for (k in seqLen(num_offspring)) {
            offspring = p1.addCrossed(individual, mate);
            pos = individual.spatialPosition + rnorm(2, 0, SIGMA);
            offspring.setSpatialPosition(p1.pointReflected(pos));
        }
    }
}

1 early() {
    sim.addSubpop("p1", K * 10 * 10);
    p1.setSpatialBounds(c(0.0, 0.0, 10.0, 10.0));
    for (ind in p1.individuals) {
        ind.setSpatialPosition(p1.pointUniform());
    }
}

early() {
    // survival probabilities
    p1.fitnessScaling = 1 - MU;
}

1: early() {
    cat(sim.generation + " : population size, early :" + p1.individualCount);
}

1: late() {
    catn( " : late :" + p1.individualCount);
    for (ind in p1.individuals) {
        writeFile(OUTFILE, sim.generation + " " + ind.x + " " + ind.y, append=T);
    }
}

late() {
    i1.evaluate();
}

100 {
    sim.simulationFinished();
}
"""
out, logfile = slim_script(spatial_logistic_fecundity_recipe, "spatial_logistic_fecundity_recipe")
# Out:
# // Initial random seed:
# 1860056358001
#
# // RunInitializeCallbacks():
# initializeSLiMModelType(modelType = 'nonWF');
# initializeSLiMOptions(dimensionality = 'xy');
# initializeMutationRate(1e-07);
# initializeMutationType(1, 0.5, "f", 0);
# initializeGenomicElementType(1, m1, 1);
# initializeGenomicElement(g1, 0, 99999);
# initializeRecombinationRate(1e-08);
# initializeInteractionType(1, "xy", reciprocal=T, maxDistance=1.5);
#
# // Starting run at generation <start>:
# 1
#
# 1 : population size, early :100 : late :58
# 2 : population size, early :121 : late :60
# 3 : population size, early :118 : late :68
# 4 : population size, early :124 : late :66
# 5 : population size, early :137 : late :79
# 6 : population size, early :158 : late :73
# 7 : population size, early :140 : late :83
# 8 : population size, early :165 : late :78
# 9 : population size, early :166 : late :95
# 10 : population size, early :172 : late :91
# 11 : population size, early :187 : late :98
# 12 : population size, early :208 : late :101
# 13 : population size, early :194 : late :87
# 14 : population size, early :195 : late :99
# 15 : population size, early :198 : late :92
# 16 : population size, early :187 : late :93
# 17 : population size, early :179 : late :94
# 18 : population size, early :169 : late :85
# 19 : population size, early :162 : late :78
# 20 : population size, early :152 : late :64
# 21 : population size, early :146 : late :71
# 22 : population size, early :137 : late :64
# 23 : population size, early :134 : late :63
# 24 : population size, early :136 : late :73
# 25 : population size, early :143 : late :77
# 26 : population size, early :162 : late :83
# 27 : population size, early :165 : late :83
# 28 : population size, early :166 : late :89
# 29 : population size, early :187 : late :92
# 30 : population size, early :170 : late :76
# 31 : population size, early :158 : late :85
# 32 : population size, early :189 : late :99
# 33 : population size, early :191 : late :89
# 34 : population size, early :177 : late :83
# 35 : population size, early :172 : late :85
# 36 : population size, early :160 : late :89
# 37 : population size, early :190 : late :103
# 38 : population size, early :213 : late :108
# 39 : population size, early :194 : late :104
# 40 : population size, early :195 : late :97
# 41 : population size, early :207 : late :101
# 42 : population size, early :191 : late :84
# 43 : population size, early :156 : late :72
# 44 : population size, early :141 : late :73
# 45 : population size, early :130 : late :63
# 46 : population size, early :136 : late :71
# 47 : population size, early :148 : late :88
# 48 : population size, early :166 : late :76
# 49 : population size, early :161 : late :85
# 50 : population size, early :180 : late :97
# 51 : population size, early :189 : late :88
# 52 : population size, early :177 : late :84
# 53 : population size, early :162 : late :78
# 54 : population size, early :143 : late :67
# 55 : population size, early :126 : late :59
# 56 : population size, early :121 : late :68
# 57 : population size, early :127 : late :60
# 58 : population size, early :133 : late :57
# 59 : population size, early :115 : late :52
# 60 : population size, early :105 : late :59
# 61 : population size, early :127 : late :66
# 62 : population size, early :121 : late :71
# 63 : population size, early :142 : late :82
# 64 : population size, early :176 : late :92
# 65 : population size, early :198 : late :111
# 66 : population size, early :197 : late :93
# 67 : population size, early :189 : late :100
# 68 : population size, early :192 : late :92
# 69 : population size, early :182 : late :86
# 70 : population size, early :157 : late :83
# 71 : population size, early :177 : late :84
# 72 : population size, early :160 : late :80
# 73 : population size, early :162 : late :78
# 74 : population size, early :159 : late :80
# 75 : population size, early :162 : late :81
# 76 : population size, early :174 : late :87
# 77 : population size, early :178 : late :87
# 78 : population size, early :171 : late :89
# 79 : population size, early :177 : late :86
# 80 : population size, early :158 : late :80
# 81 : population size, early :151 : late :73
# 82 : population size, early :149 : late :75
# 83 : population size, early :169 : late :83
# 84 : population size, early :158 : late :82
# 85 : population size, early :151 : late :78
# 86 : population size, early :166 : late :75
# 87 : population size, early :152 : late :85
# 88 : population size, early :169 : late :79
# 89 : population size, early :167 : late :74
# 90 : population size, early :155 : late :79
# 91 : population size, early :140 : late :61
# 92 : population size, early :126 : late :54
# 93 : population size, early :127 : late :60
# 94 : population size, early :133 : late :73
# 95 : population size, early :136 : late :70
# 96 : population size, early :144 : late :74
# 97 : population size, early :149 : late :70
# 98 : population size, early :138 : late :68
# 99 : population size, early :147 : late :72
# 100 : population size, early :141 : late :60

# %% [markdown]
# *Homework:*
#
# 1. let survival rate go *up* (or, change somehow) with number of neighbors
# 2. choose mates from nearby
# 3. make sure no offspring are within some small distance of anyone else

# %% [markdown]
# ### Plotting spatial locations in python
#
# Since we wrote out the spatial locations, we can plot them.
# Here's a scatterplot of the initial locations.

# %%
txy = np.loadtxt("logistic_locs.txt", skiprows=1)
xy = txy[:,1:3]
t = txy[:,0]

fig, ax = plt.subplots()
ax.set_xlim(0, 10)
ax.set_ylim(0, 10)
points = ax.scatter(xy[t == 1, 0], xy[t == 1, 1], s=10);

# %% [markdown]
# With some additional magic, we can make a *movie* of the locations, through time!
# Careful, this can take a long time if the simulation gets big.

# %%
import matplotlib.animation as ani
from IPython.display import HTML

def update(frame):
    points.set_offsets(xy[t == frame, :])
    return points

animation = ani.FuncAnimation(fig, update,
                              frames=np.linspace(1, 100, 100))
HTML(animation.to_html5_video())
# Out:
# <video width="576" height="576" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# # Predator-prey model
#
# SLiM has no problem modeling multispecies interactions.
# However, it's not *designed* for that, so the way we do it is a *little* roundabout
# (like, it has no "A eats B" function)
# ... and both species have to have exactly the same genome arrangement.
# (We could have their fitnesses be affected by completely different sets of mutations, though.)
#
# ## The plan
#
# With $N$ and $M$ the numbers of prey and predators, respectively:
#
# 0. Prey have an average of $B/(1 + N/K)$ offspring.
# 1. Each prey encounters a Binomial$(M, a)$ number of predators, randomly chosen, per time step.
# 2. Each encounter leads to the prey being eaten with probability $c$.
# 3. When the prey is eaten, we record that fact by setting its `fitnessScaling` to 0.
# 4. Prey provide the predator with $\epsilon$ units of energy,
#     which we store in their `tagF` property. (Note: prey can't be eaten twice.)
# 5. Predators have a Poisson number of offspring, with mean equal to their current amount of energy,
#     which is then set to zero.
# 6. Predators then each die, with probability $\delta$ each.
# 7. Prey also die, with probability $d$.

# %% [markdown]
# **Exercise:** What is the equilibrium of this system?

# %%
pp_recipe = """
initialize() {
    initializeSLiMModelType("nonWF");
    initializeSLiMOptions(dimensionality="xy");
    initializeMutationRate(0.0);
    initializeMutationType("m1", 0.5, "f", 0.0);
    initializeGenomicElementType("g1", m1, 1.0);
    initializeGenomicElement(g1, 0, 1);
    initializeRecombinationRate(0.0);    

    defineConstant("B", 2); // prey birth rate
    defineConstant("K", 100); // prey carrying capacity
    defineConstant("C", 0.5);    // predation prob
    defineConstant("EPSILON", 0.2); // conversion rate
    defineConstant("DELTA", 0.2);  // predator death prob
    defineConstant("D", 0.01);    // prey death prob
    defineConstant("W", 3);    // prey death prob
    defineConstant("SIGMA", 0.1);    // spatial interaction and dispersal
    
    // output numbers to here
    defineConstant("OUTFILE", "pp_nums.txt");
    writeFile(OUTFILE, "prey predators");
    defineConstant("PREYFILE", "pp_prey.txt");
    writeFile(PREYFILE, "t x y");    
    defineConstant("PREDFILE", "pp_pred.txt");
    writeFile(PREDFILE, "t x y");
    catn("Writing out prey, predator numbers to " + OUTFILE + " and " + PREDFILE + " and " + PREYFILE);
        
    // spatial interaction for local competition
    initializeInteractionType("i1", "xy", reciprocal=T,
                maxDistance = 3 * SIGMA);
    i1.setInteractionFunction("n", 1.0/(2*PI*SIGMA^2), SIGMA);
}

// prey
reproduction(p1) {
    num_offspring = rpois(1, B / (1 + p1.individualCount/K));
    for (k in seqLen(num_offspring)) {
        offspring = p1.addCrossed(individual, p1.sampleIndividuals(1));
        pos = individual.spatialPosition + rnorm(2, 0.0, SIGMA);
        offspring.setSpatialPosition(p1.pointReflected(pos));
    }
}

// predators
reproduction(p2) {
    if (individual.tagF > 0) {
        num_offspring = rpois(1, individual.tagF);
        for (k in seqLen(num_offspring)) {
            offspring = p2.addCrossed(individual, p2.sampleIndividuals(1));
            offspring.tagF = 0.0; // need to initialize these
            pos = individual.spatialPosition + rnorm(2, 0.0, SIGMA);
            offspring.setSpatialPosition(p2.pointReflected(pos));
        }
    }
}

1 early() {
    // initial population
    sim.addSubpop("p1", asInteger(K * W * W));
    p1.setSpatialBounds(c(0.0, 0, W, W));
    sim.addSubpop("p2", asInteger(K * W * W));
    p2.setSpatialBounds(c(0.0, 0, W, W));
    for (ind in c(p1.individuals, p2.individuals)) {
        ind.setSpatialPosition(p1.pointUniform());
    }
}

early() {
    // survival probabilities
    p1.fitnessScaling = 1-D;
    p2.fitnessScaling = 1-DELTA;
}

early() {
    i1.evaluate();
    // num_predators = p2.individualCount;
    // fatal_encounters = rbinom(p1.individualCount, num_predators, A * C);
    for (prey in p1.individuals) {
        predators = i1.nearestNeighborsOfPoint(p2, prey.spatialPosition); // this is everyone with 3 sigma
        num_fatal_encounters = rbinom(1, size(predators), C);
        if (num_fatal_encounters > 0) {
            predator = sample(predators, 1);
            predator.tagF = predator.tagF + EPSILON;
            prey.fitnessScaling = 0.0;
        }
    }
}

1: early() {
    writeFile(OUTFILE, p1.individualCount + " " + p2.individualCount, append=T);
    if (sim.generation < 100) {
        cat(sim.generation + " : prey : " + p1.individualCount);
        catn(" : predators : " + p2.individualCount);
    }
    for (ind in p1.individuals) 
        writeFile(PREYFILE, sim.generation + " " + ind.x + " " + ind.y, append=T);
    for (ind in p2.individuals) 
        writeFile(PREDFILE, sim.generation + " " + ind.x + " " + ind.y, append=T);
}

100 {
    sim.simulationFinished();
}
"""
out, logfile = slim_script(pp_recipe, "pp_recipe")
# Out:
# // Initial random seed:
# 1860276361098
#
# // RunInitializeCallbacks():
# initializeSLiMModelType(modelType = 'nonWF');
# initializeSLiMOptions(dimensionality = 'xy');
# initializeMutationRate(0);
# initializeMutationType(1, 0.5, "f", 0);
# initializeGenomicElementType(1, m1, 1);
# initializeGenomicElement(g1, 0, 1);
# initializeRecombinationRate(0);
# Writing out prey, predator numbers to pp_nums.txt and pp_pred.txt and pp_prey.txt
# initializeInteractionType(1, "xy", reciprocal=T, maxDistance=0.3);
#
# // Starting run at generation <start>:
# 1
#
# 1 : prey : 900 : predators : 900
# 2 : prey : 621 : predators : 822
# 3 : prey : 462 : predators : 741
# 4 : prey : 376 : predators : 739
# 5 : prey : 314 : predators : 733
# 6 : prey : 285 : predators : 740
# 7 : prey : 270 : predators : 703
# 8 : prey : 245 : predators : 695
# 9 : prey : 209 : predators : 645
# 10 : prey : 214 : predators : 617
# 11 : prey : 231 : predators : 585
# 12 : prey : 200 : predators : 574
# 13 : prey : 205 : predators : 537
# 14 : prey : 239 : predators : 510
# 15 : prey : 214 : predators : 486
# 16 : prey : 203 : predators : 487
# 17 : prey : 200 : predators : 476
# 18 : prey : 210 : predators : 450
# 19 : prey : 224 : predators : 437
# 20 : prey : 212 : predators : 434
# 21 : prey : 225 : predators : 413
# 22 : prey : 190 : predators : 393
# 23 : prey : 179 : predators : 377
# 24 : prey : 207 : predators : 361
# 25 : prey : 196 : predators : 384
# 26 : prey : 210 : predators : 375
# 27 : prey : 208 : predators : 358
# 28 : prey : 206 : predators : 357
# 29 : prey : 184 : predators : 370
# 30 : prey : 198 : predators : 359
# 31 : prey : 196 : predators : 352
# 32 : prey : 232 : predators : 319
# 33 : prey : 240 : predators : 317
# 34 : prey : 248 : predators : 318
# 35 : prey : 260 : predators : 345
# 36 : prey : 337 : predators : 324
# 37 : prey : 355 : predators : 336
# 38 : prey : 403 : predators : 339
# 39 : prey : 379 : predators : 392
# 40 : prey : 347 : predators : 431
# 41 : prey : 328 : predators : 447
# 42 : prey : 308 : predators : 448
# 43 : prey : 302 : predators : 445
# 44 : prey : 333 : predators : 451
# 45 : prey : 341 : predators : 454
# 46 : prey : 342 : predators : 465
# 47 : prey : 398 : predators : 478
# 48 : prey : 473 : predators : 468
# 49 : prey : 527 : predators : 467
# 50 : prey : 476 : predators : 457
# 51 : prey : 377 : predators : 475
# 52 : prey : 327 : predators : 544
# 53 : prey : 288 : predators : 591
# 54 : prey : 244 : predators : 571
# 55 : prey : 238 : predators : 576
# 56 : prey : 214 : predators : 535
# 57 : prey : 186 : predators : 519
# 58 : prey : 177 : predators : 508
# 59 : prey : 190 : predators : 493
# 60 : prey : 196 : predators : 505
# 61 : prey : 229 : predators : 472
# 62 : prey : 254 : predators : 433
# 63 : prey : 319 : predators : 419
# 64 : prey : 374 : predators : 377
# 65 : prey : 423 : predators : 373
# 66 : prey : 429 : predators : 359
# 67 : prey : 426 : predators : 376
# 68 : prey : 378 : predators : 378
# 69 : prey : 344 : predators : 384
# 70 : prey : 336 : predators : 425
# 71 : prey : 314 : predators : 448
# 72 : prey : 310 : predators : 499
# 73 : prey : 342 : predators : 522
# 74 : prey : 362 : predators : 514
# 75 : prey : 314 : predators : 505
# 76 : prey : 287 : predators : 542
# 77 : prey : 271 : predators : 535
# 78 : prey : 264 : predators : 526
# 79 : prey : 248 : predators : 509
# 80 : prey : 262 : predators : 537
# 81 : prey : 251 : predators : 548
# 82 : prey : 230 : predators : 529
# 83 : prey : 219 : predators : 547
# 84 : prey : 187 : predators : 557
# 85 : prey : 200 : predators : 556
# 86 : prey : 196 : predators : 540
# 87 : prey : 209 : predators : 560
# 88 : prey : 219 : predators : 576
# 89 : prey : 239 : predators : 543
# 90 : prey : 266 : predators : 522
# 91 : prey : 326 : predators : 498
# 92 : prey : 406 : predators : 485
# 93 : prey : 421 : predators : 474
# 94 : prey : 396 : predators : 488
# 95 : prey : 333 : predators : 493
# 96 : prey : 316 : predators : 479
# 97 : prey : 307 : predators : 494
# 98 : prey : 293 : predators : 535
# 99 : prey : 243 : predators : 558

# %%
prey = np.loadtxt("pp_prey.txt", skiprows=1)
prey_t = prey[:, 0]
prey_xy = prey[:, 1:3]
pred = np.loadtxt("pp_pred.txt", skiprows=1)
pred_t = pred[:, 0]
pred_xy = pred[:, 1:3]

fig, ax = plt.subplots()
prey_points = ax.scatter(prey_xy[prey_t == 1, 0], prey_xy[prey_t == 1, 1], label='prey')
pred_points = ax.scatter(pred_xy[pred_t == 1, 0], pred_xy[pred_t == 1, 1], label='predators')
ax.legend();

# %%
import matplotlib.animation as ani
from IPython.display import HTML

def update(frame):
    prey_points.set_offsets(prey_xy[prey_t == frame, :])
    pred_points.set_offsets(pred_xy[pred_t == frame, :])
    return points

animation = ani.FuncAnimation(fig, update,
                              frames=np.linspace(1, 100, 100))
HTML(animation.to_html5_video())
# Out:
# <video width="576" height="576" controls autoplay loop>
#   <source type="video/mp4" src="...
